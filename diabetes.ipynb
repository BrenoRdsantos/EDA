# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from autoviz import AutoViz_Class
# %matplotlib inline

# %%
df = pd.read_csv('./Data/diabetes_prediction_dataset.csv')

# %%
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history   bmi   \
# 0      Female  80.0        0             1              never     25.19
# 1      Female  54.0        0             0            No Info     27.32
# 2        Male  28.0        0             0              never     27.32
# 3      Female  36.0        0             0            current     23.45
# 4        Male  76.0        1             1            current     20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0        0             0            No Info     27.32
# 99996  Female   2.0        0             0            No Info     17.37
# 99997    Male  66.0        0             0             former     27.83
# 99998  Female  24.0        0             0              never     35.42
# 99999  Female  57.0        0             0            current     22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0          6.6              140              0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
df.describe().T
# Out:
#                        count      mean        std      min     25%     50%   \
# age                  100000.0   41.885856  22.516840   0.08   24.00   43.00
# hypertension         100000.0    0.074850   0.263150   0.00    0.00    0.00
# heart_disease        100000.0    0.039420   0.194593   0.00    0.00    0.00
# bmi                  100000.0   27.320767   6.636783  10.01   23.63   27.32
# HbA1c_level          100000.0    5.527507   1.070672   3.50    4.80    5.80
# blood_glucose_level  100000.0  138.058060  40.708136  80.00  100.00  140.00
# diabetes             100000.0    0.085000   0.278883   0.00    0.00    0.00
#
#                        75%     max
# age                   60.00   80.00
# hypertension           0.00    1.00
# heart_disease          0.00    1.00
# bmi                   29.58   95.69
# HbA1c_level            6.20    9.00
# blood_glucose_level  159.00  300.00
# diabetes               0.00    1.00

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
df.rename(columns={'gender':'genero','age':'idade','hypertension':'hipertensão', 'heart_disease':'doença_cardiaca', 'smoking_history':'fumante', 'bmi':'imc','HbA1c_level':'hemoglobina_glicada','blood_glucose_level':'nivel_glicose_sanguino'},inplace=True)

# %%
df.columns
# Out:
# Index(['genero', 'idade', 'hipertensão', 'doença_cardiaca', 'fumante', 'imc',
#        'hemoglobina_glicada', 'nivel_glicose_sanguino', 'diabetes'],
#       dtype='object')

# %%
AV = AutoViz_Class()

target_variable = "diabetes"

dft = AV.AutoViz(
    df,
    sep=",",
    depVar=target_variable,
    dfte=None,
    header=0,
    verbose=2,
    lowess=False,
    chart_format="svg",
    max_rows_analyzed=100000,
    max_cols_analyzed=10,
    save_plot_dir=None
)
# Out:
# Shape of your Data Set loaded: (100000, 9)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#   Printing up to 30 columns (max) in each category:
#     Numeric Columns : ['idade', 'imc', 'hemoglobina_glicada']
#     Integer-Categorical Columns: ['nivel_glicose_sanguino']
#     String-Categorical Columns: ['genero', 'fumante']
#     Factor-Categorical Columns: []
#     String-Boolean Columns: []
#     Numeric-Boolean Columns: ['hipertensão', 'doença_cardiaca']
#     Discrete String Columns: []
#     NLP text Columns: []
#     Date Time Columns: []
#     ID Columns: []
#     Columns that will not be considered in modeling: []
#     8 Predictors classified...
# ...

# %%
df['fumante'].value_counts()
# Out:
# fumante
# No Info        35816
# never          35095
# former          9352
# current         9286
# not current     6447
# ever            4004
# Name: count, dtype: int64

# %%
df
# Out:
#        genero  idade  hipertensão  doença_cardiaca fumante    imc   \
# 0      Female  80.0        0              1           never  25.19
# 1      Female  54.0        0              0         No Info  27.32
# 2        Male  28.0        0              0           never  27.32
# 3      Female  36.0        0              0         current  23.45
# 4        Male  76.0        1              1         current  20.14
# ...       ...    ...          ...              ...      ...    ...
# 99995  Female  80.0        0              0         No Info  27.32
# 99996  Female   2.0        0              0         No Info  17.37
# 99997    Male  66.0        0              0          former  27.83
# 99998  Female  24.0        0              0           never  35.42
# 99999  Female  57.0        0              0         current  22.43
#
#        hemoglobina_glicada  nivel_glicose_sanguino  diabetes
# 0              6.6                    140               0
# ...

# %%
X_teste = df.loc[df['fumante'] == 'No Info']
X_teste
# Out:
#        genero  idade  hipertensão  doença_cardiaca fumante    imc   \
# 1      Female  54.0        0              0         No Info  27.32
# 7      Female  79.0        0              0         No Info  23.86
# 14     Female  76.0        0              0         No Info  27.32
# 15       Male  78.0        0              0         No Info  27.32
# 18     Female  42.0        0              0         No Info  27.32
# ...       ...    ...          ...              ...      ...    ...
# 99989  Female  26.0        0              0         No Info  27.32
# 99990    Male  39.0        0              0         No Info  27.32
# 99994  Female  36.0        0              0         No Info  24.60
# 99995  Female  80.0        0              0         No Info  27.32
# 99996  Female   2.0        0              0         No Info  17.37
#
#        hemoglobina_glicada  nivel_glicose_sanguino  diabetes
# 1              6.6                     80               0
# ...

# %%
X_treino = df
X_treino
# Out:
#        genero  idade  hipertensão  doença_cardiaca fumante    imc   \
# 0      Female  80.0        0              1           never  25.19
# 1      Female  54.0        0              0         No Info  27.32
# 2        Male  28.0        0              0           never  27.32
# 3      Female  36.0        0              0         current  23.45
# 4        Male  76.0        1              1         current  20.14
# ...       ...    ...          ...              ...      ...    ...
# 99995  Female  80.0        0              0         No Info  27.32
# 99996  Female   2.0        0              0         No Info  17.37
# 99997    Male  66.0        0              0          former  27.83
# 99998  Female  24.0        0              0           never  35.42
# 99999  Female  57.0        0              0         current  22.43
#
#        hemoglobina_glicada  nivel_glicose_sanguino  diabetes  fumante encoded
# 0              6.6                    140               0            4
# ...

# %%
X_treino = X_treino[X_treino['fumante'] != 'No Info']

# %%
X_treino.drop(columns=['genero'], inplace=True)

# %%
X_treino.drop(columns=['fumante'], inplace=True)

# %%
X_treino
# Out:
#        idade  hipertensão  doença_cardiaca   imc   hemoglobina_glicada  \
# 0      80.0        0              1         25.19          6.6
# 2      28.0        0              0         27.32          5.7
# 3      36.0        0              0         23.45          5.0
# 4      76.0        1              1         20.14          4.8
# 5      20.0        0              0         27.32          6.6
# ...      ...          ...              ...    ...                  ...
# 99992  26.0        0              0         34.34          6.5
# 99993  40.0        0              0         40.69          3.5
# 99997  66.0        0              0         27.83          5.7
# 99998  24.0        0              0         35.42          4.0
# 99999  57.0        0              0         22.43          6.6
#
#        nivel_glicose_sanguino  diabetes  fumante encoded
# 0                140               0            4
# 2                158               0            4
# ...

# %%
X_treino
Y_treino = X_treino['fumante encoded']

# %%
X_treino.drop(columns=['fumante encoded'], inplace=True)

# %%
X_treino
# Out:
#        idade  hipertensão  doença_cardiaca   imc   hemoglobina_glicada  \
# 0      80.0        0              1         25.19          6.6
# 2      28.0        0              0         27.32          5.7
# 3      36.0        0              0         23.45          5.0
# 4      76.0        1              1         20.14          4.8
# 5      20.0        0              0         27.32          6.6
# ...      ...          ...              ...    ...                  ...
# 99992  26.0        0              0         34.34          6.5
# 99993  40.0        0              0         40.69          3.5
# 99997  66.0        0              0         27.83          5.7
# 99998  24.0        0              0         35.42          4.0
# 99999  57.0        0              0         22.43          6.6
#
#        nivel_glicose_sanguino  diabetes
# 0                140               0
# 2                158               0
# 3                155               0
# 4                155               0
# ...

# %%
Y_treino
# Out:
# 0        4
# 2        4
# 3        1
# 4        1
# 5        4
#         ..
# 99992    4
# 99993    4
# 99997    3
# 99998    4
# 99999    1
# Name: fumante encoded, Length: 64184, dtype: int32

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_treino, Y_treino)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
X_teste.drop(columns=['genero','fumante'], inplace=True)

# %%
predict = knn.predict(X_teste)

# %%
df[df['fumante encoded'] == 0]
# Out:
#        genero  idade  hipertensão  doença_cardiaca fumante    imc   \
# 1      Female  54.0        0              0         No Info  27.32
# 7      Female  79.0        0              0         No Info  23.86
# 14     Female  76.0        0              0         No Info  27.32
# 15       Male  78.0        0              0         No Info  27.32
# 18     Female  42.0        0              0         No Info  27.32
# ...       ...    ...          ...              ...      ...    ...
# 99989  Female  26.0        0              0         No Info  27.32
# 99990    Male  39.0        0              0         No Info  27.32
# 99994  Female  36.0        0              0         No Info  24.60
# 99995  Female  80.0        0              0         No Info  27.32
# 99996  Female   2.0        0              0         No Info  17.37
#
#        hemoglobina_glicada  nivel_glicose_sanguino  diabetes  fumante encoded
# 1              6.6                     80               0            0
# ...

# %%
df
# Out:
#        genero  idade  hipertensão  doença_cardiaca fumante    imc   \
# 0      Female  80.0        0              1           never  25.19
# 1      Female  54.0        0              0               2  27.32
# 2        Male  28.0        0              0           never  27.32
# 3      Female  36.0        0              0         current  23.45
# 4        Male  76.0        1              1         current  20.14
# ...       ...    ...          ...              ...      ...    ...
# 99995  Female  80.0        0              0               4  27.32
# 99996  Female   2.0        0              0               1  17.37
# 99997    Male  66.0        0              0          former  27.83
# 99998  Female  24.0        0              0           never  35.42
# 99999  Female  57.0        0              0         current  22.43
#
#        hemoglobina_glicada  nivel_glicose_sanguino  diabetes  fumante encoded
# 0              6.6                    140               0            4
# ...

# %%
df['fumante'].unique()
# Out:
# array(['never', 2, 'current', 4, 'former', 'ever', 'not current', 3, 5, 1],
#       dtype=object)

# %%
df['fumante'].replace(1, 'never', inplace=True)
df['fumante'].replace(2, 'former', inplace=True)
df['fumante'].replace(3, 'current', inplace=True)
df['fumante'].replace(4, 'not current', inplace=True)
df['fumante'].replace(5, 'ever', inplace=True)

# %%
df.drop(columns=['fumante encoded'], inplace=True)

# %%
df
# Out:
#        genero  idade  hipertensão  doença_cardiaca   fumante      imc   \
# 0      Female  80.0        0              1               never  25.19
# 1      Female  54.0        0              0              former  27.32
# 2        Male  28.0        0              0               never  27.32
# 3      Female  36.0        0              0             current  23.45
# 4        Male  76.0        1              1             current  20.14
# ...       ...    ...          ...              ...          ...    ...
# 99995  Female  80.0        0              0         not current  27.32
# 99996  Female   2.0        0              0               never  17.37
# 99997    Male  66.0        0              0              former  27.83
# 99998  Female  24.0        0              0               never  35.42
# 99999  Female  57.0        0              0             current  22.43
#
#        hemoglobina_glicada  nivel_glicose_sanguino  diabetes
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['fumante_encoded'] = le.fit_transform(df['fumante'])

# %%
df
# Out:
#        genero  idade  hipertensão  doença_cardiaca   fumante      imc   \
# 0      Female  80.0        0              1               never  25.19
# 1      Female  54.0        0              0              former  27.32
# 2        Male  28.0        0              0               never  27.32
# 3      Female  36.0        0              0             current  23.45
# 4        Male  76.0        1              1             current  20.14
# ...       ...    ...          ...              ...          ...    ...
# 99995  Female  80.0        0              0         not current  27.32
# 99996  Female   2.0        0              0               never  17.37
# 99997    Male  66.0        0              0              former  27.83
# 99998  Female  24.0        0              0               never  35.42
# 99999  Female  57.0        0              0             current  22.43
#
#        hemoglobina_glicada  nivel_glicose_sanguino  diabetes  fumante_encoded
# ...

# %% [markdown]
# 3    never/
# 4    not current/
# 0    current/
# 2    former/
# 1    ever/

# %%
df['fumante_encoded'].value_counts()
# Out:
# fumante_encoded
# 3    40624
# 4    30823
# 0    12038
# 2    10833
# 1     5682
# Name: count, dtype: int64

# %%
X = df[['idade', 'hipertensão', 'doença_cardiaca', 'imc', 'hemoglobina_glicada', 'nivel_glicose_sanguino', 'fumante_encoded']]
Y = df['diabetes']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((70000, 7), (30000, 7), (70000,), (30000,))

# %%
knn.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
predict = knn.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
accuracy_score(Y_test, predict)
# Out:
# 0.9504

# %%
confusion_matrix(Y_test, predict)
# Out:
# array([[27119,   334],
#        [ 1154,  1393]], dtype=int64)

# %%
from yellowbrick.classifier import ConfusionMatrix
cm = ConfusionMatrix(knn)
cm.fit(X_train, Y_train)
cm.score(X_test, Y_test)
# Out:
# 0.9504
